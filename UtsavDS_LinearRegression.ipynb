# %% [markdown]
# <a href="https://colab.research.google.com/github/UtsavBhatt/Data-Science/blob/master/UtsavDS_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
import io 
uploaded =  files.upload()
data=pd.read_csv(io.BytesIO(uploaded['Salary_Data.csv']))
x = data['YearsExperience']
y = data['Salary']
# Out:
#      <input type="file" id="files-33c224d1-cc68-4962-97a9-477bb24b87c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33c224d1-cc68-4962-97a9-477bb24b87c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Salary_Data.csv to Salary_Data.csv

# %%
print(data.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
def linear_regression():
  x_mean = x.mean()
  y_mean = y.mean()
  
  B1_num = ((x - x_mean) * (y - y_mean)).sum()
  B1_den = ((x - x_mean)**2).sum()
  B1 = B1_num / B1_den
  B0 = y_mean - (B1*x_mean)
  reg_line  = 'y = {} + {}b'.format(B0, round(B1, 3))
  return (B0 ,B1 , reg_line)

# %%
def corr_coef(x,y):
  N = len(x)
  num = (N* (x*y).sum()) - (x.sum() * y.sum())
  den = np.sqrt((N * (x**2).sum()  - x.sum()**2) * (N * (y**2).sum() - y.sum()**2 ))
  R = num / den
  return R

# %%
B0 , B1 , reg_line = linear_regression()
print('regression Line : ',reg_line)
R = corr_coef(x,y)
print('Corelation coef : ', R)
print('Goodness of fit : ',R**2)
# Out:
# regression Line :  y = 25792.20019866869 + 9449.962b
# Corelation coef :  0.97824161848876
# Goodness of fit :  0.9569566641435087

# %%
plt.figure(figsize=(12,5))
plt.scatter(x,y,s=300,linewidths=1,edgecolor = 'black')

# %%
plt.figure(figsize=(12,5))
plt.scatter(x,y,s=300,linewidths=1,edgecolor = 'black')
text = '''X Mean:{} years
Y Mean: ${}
R:{}
R^2:{}
y = {}+{}X'''.format(round(x.mean(),2),
                     round(y.mean(),2),
                     round(R,4),
                     round(R**2,4),
                     round(B0,3),
                     round(B1, 3))
plt.text(x=1,y=100000, s = text,fontsize=12, bbox={'facecolor': 'grey','alpha':0.2,'pad':10})
plt.title('How Experience Affects Salary')
plt.xlabel('years of experience ',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.plot(x,B0+B1*x,c = 'r',linewidth=5,alpha=.5,solid_capstyle='round')
plt.scatter(x=x.mean(),y=y.mean(),marker="*",s=10**2.5,c='r')

# %%
def predict(B0,B1,new_x):
  y = B0 + B1 + new_x
  return y

predict(B0,B1,67)
# Out:
# 35309.16252012376
